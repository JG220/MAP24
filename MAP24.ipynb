# %% [markdown]
# <a href="https://colab.research.google.com/github/JG220/MAP24/blob/main/MAP24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Notes

# %%
<img src="https://logos-world.net/wp-content/uploads/2020/06/Florida-Atlantic-Owls-Logo.png" width = 300>
# Out:
#   File "<ipython-input-2-94035df32b8f>", line 1
#     <img src="https://logos-world.net/wp-content/uploads/2020/06/Florida-Atlantic-Owls-Logo.png" width = 300>
#     ^
# SyntaxError: invalid syntax

# %%
<img src="https://images.squarespace-cdn.com/content/v1/55b6a6dce4b089e11621d3ed/84f4c214-31af-4036-8a27-daa7716f8c54/NPL+and+Reserves+combo+chart.png?format=1500w">

# %%
apples = 10

# %%
oranges = 8

# %%
total = apples + oranges

# %%
total
# Out:
# 18

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
A = np.random.random((1,5))

# %%
A
# Out:
# array([[0.77661825, 0.5064678 , 0.01758382, 0.90534566, 0.2891596 ]])

# %%
B = np.random.random((1,5))

# %%
A,B
# Out:
# (array([[0.77661825, 0.5064678 , 0.01758382, 0.90534566, 0.2891596 ]]),
#  array([[0.87453503, 0.70295833, 0.8217506 , 0.40529858, 0.18978553]]))

# %%
A = A.T
B = B.T

# %%
plt.plot(A,B)

# %%
plt.plot(A,B,'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y)

# %%
Z = np.random.random((100,100))

# %%
Z.shape
# Out:
# (100, 100)

# %%
Z
# Out:
# array([[0.7855936 , 0.30187793, 0.96440679, ..., 0.53580561, 0.3987405 ,
#         0.59171926],
#        [0.29534432, 0.6392366 , 0.94566197, ..., 0.17863486, 0.1713884 ,
#         0.02849587],
#        [0.40634961, 0.23977216, 0.64103327, ..., 0.52153582, 0.94834556,
#         0.86546554],
#        ...,
#        [0.15805978, 0.37184584, 0.97158339, ..., 0.54514446, 0.98620871,
#         0.23024334],
#        [0.44756171, 0.10654068, 0.38722555, ..., 0.18035737, 0.75289161,
#         0.16657277],
#        [0.19004341, 0.22721974, 0.50587254, ..., 0.98499919, 0.42630702,
#         0.10622009]])

# %%
plt.imshow(Z)
